# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df= pd.read_csv(r'COVID19.csv', delimiter=';', header= 0, names= ['day','month','year','cases','deaths','countriesAndTerritories','geoId','countryterritoryCode','popData2018'])
df
# Out:
#        day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0       13      4  2020     52       0             Afghanistan    AF
# 1       12      4  2020     34       3             Afghanistan    AF
# 2       11      4  2020     37       0             Afghanistan    AF
# 3       10      4  2020     61       1             Afghanistan    AF
# 4        9      4  2020     56       3             Afghanistan    AF
# ...    ...    ...   ...    ...     ...                     ...   ...
# 10532   25      3  2020      0       0                Zimbabwe    ZW
# 10533   24      3  2020      0       1                Zimbabwe    ZW
# 10534   23      3  2020      0       0                Zimbabwe    ZW
# 10535   22      3  2020      1       0                Zimbabwe    ZW
# 10536   21      3  2020      1       0                Zimbabwe    ZW
#
#       countryterritoryCode  popData2018
# 0                      AFG   37172386.0
# 1                      AFG   37172386.0
# 2                      AFG   37172386.0
# 3                      AFG   37172386.0
# 4                      AFG   37172386.0
# ...                    ...          ...
# 10532                  ZWE   14439018.0
# 10533                  ZWE   14439018.0
# 10534                  ZWE   14439018.0
# 10535                  ZWE   14439018.0
# 10536                  ZWE   14439018.0
#
# [10537 rows x 9 columns]

# %%
df.head(10)
# Out:
#    day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   13      4  2020     52       0             Afghanistan    AF
# 1   12      4  2020     34       3             Afghanistan    AF
# 2   11      4  2020     37       0             Afghanistan    AF
# 3   10      4  2020     61       1             Afghanistan    AF
# 4    9      4  2020     56       3             Afghanistan    AF
# 5    8      4  2020     30       4             Afghanistan    AF
# 6    7      4  2020     38       0             Afghanistan    AF
# 7    6      4  2020     29       2             Afghanistan    AF
# 8    5      4  2020     35       1             Afghanistan    AF
# 9    4      4  2020      0       0             Afghanistan    AF
#
#   countryterritoryCode  popData2018
# 0                  AFG   37172386.0
# 1                  AFG   37172386.0
# 2                  AFG   37172386.0
# 3                  AFG   37172386.0
# 4                  AFG   37172386.0
# 5                  AFG   37172386.0
# 6                  AFG   37172386.0
# 7                  AFG   37172386.0
# 8                  AFG   37172386.0
# 9                  AFG   37172386.0

# %%
df.describe()
# Out:
#                 day         month          year         cases        deaths  \
# count  10537.000000  10537.000000  10537.000000  10537.000000  10537.000000
# mean      15.106956      2.728670   2019.993641    171.520167     10.772801
# std        9.068637      1.290159      0.079490   1311.985637     85.997775
# min        1.000000      1.000000   2019.000000     -9.000000      0.000000
# 25%        7.000000      2.000000   2020.000000      0.000000      0.000000
# 50%       14.000000      3.000000   2020.000000      1.000000      0.000000
# 75%       23.000000      4.000000   2020.000000     17.000000      0.000000
# max       31.000000     12.000000   2020.000000  35527.000000   2087.000000
#
#         popData2018
# count  1.036900e+04
# mean   6.174286e+07
# std    1.967530e+08
# min    1.000000e+03
# 25%    3.170208e+06
# 50%    1.018318e+07
# 75%    4.222843e+07
# max    1.392730e+09

# %%
df.isnull().sum()
# Out:
# day                          0
# month                        0
# year                         0
# cases                        0
# deaths                       0
# countriesAndTerritories      0
# geoId                       30
# countryterritoryCode       209
# popData2018                168
# dtype: int64

# %%
modData = df.append({'day' : 13 , 'month': 4, 'year':2020, 'cases':60, 'deaths':0 } , ignore_index=True)
modData.describe()
# Out:
#                 day         month          year         cases        deaths  \
# count  10538.000000  10538.000000  10538.000000  10538.000000  10538.000000
# mean      15.106757      2.728791   2019.993642    171.509584     10.771778
# std        9.068230      1.290157      0.079487   1311.923830     85.993758
# min        1.000000      1.000000   2019.000000     -9.000000      0.000000
# 25%        7.000000      2.000000   2020.000000      0.000000      0.000000
# 50%       14.000000      3.000000   2020.000000      1.000000      0.000000
# 75%       23.000000      4.000000   2020.000000     17.000000      0.000000
# max       31.000000     12.000000   2020.000000  35527.000000   2087.000000
#
#         popData2018
# count  1.036900e+04
# mean   6.174286e+07
# std    1.967530e+08
# min    1.000000e+03
# 25%    3.170208e+06
# 50%    1.018318e+07
# 75%    4.222843e+07
# max    1.392730e+09

# %%
print('Columns with missing values')
print(modData.isnull().sum())
print('\n Columns with zero values')
print((modData[['day','month','year','cases','deaths']]==0).sum())
# Out:
# Columns with missing values
# day                          0
# month                        0
# year                         0
# cases                        0
# deaths                       0
# countriesAndTerritories      1
# geoId                       31
# countryterritoryCode       210
# popData2018                169
# dtype: int64
#
#  Columns with zero values
# day          0
# month        0
# year         0
# cases     5187
# deaths    8410
# dtype: int64

# %%
modData[['day',
         'month',
         'year',
         'cases','deaths']] = modData[['day',
                                              'month',
                                              'year',
                                              'cases',
                                              'deaths']].replace(0, np.NaN)
print('Columns with missing values')
print(modData.isnull().sum())
# Out:
# Columns with missing values
# day                           0
# month                         0
# year                          0
# cases                      5187
# deaths                     8410
# countriesAndTerritories       1
# geoId                        31
# countryterritoryCode        210
# popData2018                 169
# dtype: int64

# %%
modData.fillna(modData.mean(), inplace=True)
print(modData.isnull().sum())
# Out:
# day                          0
# month                        0
# year                         0
# cases                        0
# deaths                       0
# countriesAndTerritories      1
# geoId                       31
# countryterritoryCode       210
# popData2018                  0
# dtype: int64

# %%
sns.boxplot(x='year',y='cases',data=df) 
plt.show()

# %%
sns.violinplot(x='year',y='cases', data=df, size=20)
plt.show()

# %%
df.plot(kind='scatter',x='cases',y='deaths', c= 'g')
plt.show()

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="countriesAndTerritories", height=10) \
   .map(plt.scatter, "cases", "deaths") \
   .add_legend();
plt.show();

# %%
X= df['cases']
Y= df['deaths']
df2 = pd.DataFrame({'cases': X, 'deaths': Y})
print(df2)
# Out:
#        cases  deaths
# 0         52       0
# 1         34       3
# 2         37       0
# 3         61       1
# 4         56       3
# ...      ...     ...
# 10532      0       0
# 10533      0       1
# 10534      0       0
# 10535      1       0
# 10536      1       0
#
# [10537 rows x 2 columns]

# %%
plt.scatter(df2[['cases']], df2[['deaths']], color = "r", marker = "x", s = 15)
plt.xlabel('cases') 
plt.ylabel('deaths')
plt.title('Scatter Plot') 
plt.show()

# %%
from sklearn.linear_model import LinearRegression

classifier = LinearRegression()

model = classifier.fit(df2[['cases']], df2[['deaths']])

# %%
y_pred = classifier.predict(df2[['cases']])
print(y_pred)
# Out:
# [[4.39568825]
#  [3.43528111]
#  [3.59534896]
#  ...
#  [1.62117872]
#  [1.67453467]
#  [1.67453467]]

# %%
plt.scatter(df2[['cases']], df2[['deaths']], color = "m", marker = "s", s = 10) 

plt.plot(df2['cases'], y_pred, color = "g") 
plt.xlabel('cases') 
plt.ylabel('deaths')
plt.title('Regression Function')
plt.show()
print('Coefficients: \n', classifier.coef_)
print('Intercept: \n', classifier.intercept_)
# Out:
# Coefficients:
#  [[0.05335595]]
# Intercept:
#  [1.62117872]

# %%
Day_10537 = classifier.intercept_+ classifier.coef_ * 10537 
print(Day_10537)
# Out:
# [[563.83285024]]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("Mean squared error:")
print(mean_squared_error(df2[['deaths']], y_pred))
# Out:
# Mean squared error:
# 2495.066432570814

# %%
plt.scatter(y_pred, (df2[['deaths']] - y_pred) ** 2, color = "blue", s = 10,) 
plt.title("Squared errors")

plt.hlines(y = 0, xmin = 0, xmax = 140, linewidth = 2) 
plt.xlabel('predicted values')
plt.ylabel('squared error')
plt.show()

# %%
print("Mean absolute error: ")
print(mean_absolute_error(df2[['deaths']], y_pred))

#plot
plt.scatter(y_pred, (df2[['deaths']] - y_pred), color = "blue", s = 10,) 
plt.title("Absolute Errors")
plt.hlines(y = 0, xmin = 0, xmax = 140, linewidth = 2) 
plt.xlabel('predicted values')
plt.ylabel('absolute error')
plt.show()
# Out:
# Mean absolute error:
# 8.339279658837947

# %%
from sklearn.linear_model import LogisticRegression


X = df2[['cases']] 
y = df['month'] 

#defining and training the logistic regression model
log_regression = LogisticRegression(solver = 'liblinear', multi_class = 'ovr')
log_regression.fit(X, y)

pred = log_regression.predict(X)

print('Score: \n', log_regression.score(X, y)) #the mean accuracy on the given test data and labels
print('Coefficients: \n', log_regression.coef_)
print('Intercept: \n', log_regression.intercept_)
# Out:
# Score:
#  0.36433519977223117
# Coefficients:
#  [[-2.22241629e-02]
#  [-7.98492912e-04]
#  [ 8.73165194e-06]
#  [ 2.24483080e-04]
#  [-2.81677139e-01]]
# Intercept:
#  [-1.10759428 -1.42770439 -0.56771733 -1.13554696 -4.4610103 ]

# %%
X = df.iloc[:, 0:5]
y=df['month']
print('X: \n', X.head(), '\n')
print('y: \n', y.head(), '\n')

from sklearn.linear_model import LogisticRegression
classifier3 = LogisticRegression( solver = 'liblinear', multi_class = 'ovr')
classifier3.fit(X, y)

y_pred = classifier3.predict(X)

print('Score: \n', classifier3.score(X, y))
print('Coefficients: \n', classifier3.coef_)
print('Intercept: \n', classifier3.intercept_)
# Out:
# X:
#     day  month  year  cases  deaths
# 0   13      4  2020     52       0
# 1   12      4  2020     34       3
# 2   11      4  2020     37       0
# 3   10      4  2020     61       1
# 4    9      4  2020     56       3
#
# y:
#  0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: month, dtype: int64
#
# Score:
#  0.8554617063680364
# Coefficients:
#  [[ 6.51865646e-03 -7.86077523e+00  5.80858043e-03  3.97015146e-04
#   -5.10382853e-02]
#  [-1.63443544e-02 -7.33469451e-01  2.80332693e-04 -5.89308781e-05
#   -4.31475408e-03]
#  [ 1.29570611e-01  6.57185557e-01 -2.20687382e-03  7.95489479e-05
#   -1.92521946e-03]
#  [-2.73819496e-01  2.16192803e+00 -2.51855905e-03  1.51702402e-04
#    3.44811230e-03]
#  [ 5.07516601e-01  1.39617248e+00 -1.33189267e-02 -5.59300736e-02
#   -1.49001417e-02]]
# Intercept:
#  [ 2.19817144e-06 -9.42537918e-07 -3.97525370e-05 -1.19681940e-04
#   6.74359006e-05]
